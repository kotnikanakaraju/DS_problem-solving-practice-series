# %%
import heapq
def dij(graph,start):
    #initialaze the distances and visited set
    distances={node:float('inf') for node in graph}
    distances[start]=0
    visited=set()
    
    #priority queue to keep track of the next node to visit
    prior_queue=[(0,start)]
    
    while prior_queue:
        curr_dist,curr_node=heapq.heappop(prior_queue)
        if curr_node in visited:
            continue
            
        visited.add(curr_node)
        
        for neighbour,weight in graph[curr_node].items():
            dist=curr_dist+weight
            
            if dist<distances[neighbour]:
                distances[neighbour]=dist
                heapq.heappush(prior_queue,(dist,neighbour))
    return dist
graph = {
    'A': {'B': 1, 'C': 4},
    'B': {'A': 1, 'C': 2, 'D': 5},
    'C': {'A': 4, 'B': 2, 'D': 1},
    'D': {'B': 5, 'C': 1}
}

dij(graph,'A')
# Out:
# 5

# %%
import heapq

def dijkstra(graph, start):
    # Initialize distances and visited set
    distances = {node: float('inf') for node in graph}
    distances[start] = 0
    visited = set()
    
    # Priority queue to keep track of the next node to visit
    priority_queue = [(0, start)]
    
    while priority_queue:
        current_distance, current_node = heapq.heappop(priority_queue)
        
        # Skip if the node has already been visited
        if current_node in visited:
            continue
        
        visited.add(current_node)
        
        # Explore neighbors
        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight
            
            # Update distance if a shorter path is found
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                heapq.heappush(priority_queue, (distance, neighbor))
    
    return distances

# Example usage
graph = {
    'A': {'B': 1, 'C': 4},
    'B': {'A': 1, 'C': 2, 'D': 5},
    'C': {'A': 4, 'B': 2, 'D': 1},
    'D': {'B': 5, 'C': 1}
}

start_node = 'A'
shortest_distances = dijkstra(graph, start_node)
print(shortest_distances)
# Out:
# {'A': 0, 'B': 1, 'C': 3, 'D': 4}

# %%
# Bellman ford
class Graph:
    def __init__(self,vertices):
        self.V=vertices
        self.graph=[]
        
    def add_edge(self,u,v,w):
        self.graph.append([u,v,w])
        
    def bellman_ford(self,src):
        dist=[float('inf')]* self.V
        dist[src]=0
        
        
    #realax all edges v-1 items
        for _ in range(self.V-1):
            for u,v,w in self.graph:
                if dist[u]!=float("inf") and dist[u]+w<dist[v]:
                    dist[v]=dist[u]+w
                
        for u,v,w in self.graph:
            if dist[u]!=float("inf") and dist[u]+w<dist[v]:
                print("graph contains negative weight cycle")
                return
        
        
        print("vertex Distance from src")
        for i in range(self.V):
            print(f'{i}\t\t{dist[i]}')

if __name__ == "__main__":
    graph = Graph(5)
    graph.add_edge(0, 1, -1)
    graph.add_edge(0, 2, 4)
    graph.add_edge(1, 2, 3)
    graph.add_edge(1, 3, 2)
    graph.add_edge(1, 4, 2)
    graph.add_edge(3, 2, 5)
    graph.add_edge(3, 1, 1)
    graph.add_edge(4, 3, -3)

    # Call Bellman-Ford algorithm starting from
    graph.bellman_ford(0)
# Out:
# vertex Distance from src
# 0		0
# 1		-1
# 2		2
# 3		-2
# 4		1

# %%
class Graph:
    def __init__(self, vertices):
        self.V = vertices
        self.graph = []

    def add_edge(self, u, v, w):
        self.graph.append([u, v, w])

    def bellman_ford(self, src):
        # Initialize distances from the source vertex to all other vertices as infinity
        dist = [float("inf")] * self.V
        dist[src] = 0

        # Relax all edges |V| - 1 times
        for _ in range(self.V - 1):
            for u, v, w in self.graph:
                if dist[u] != float("inf") and dist[u] + w < dist[v]:
                    dist[v] = dist[u] + w

        # Check for negative weight cycles
        for u, v, w in self.graph:
            if dist[u] != float("inf") and dist[u] + w < dist[v]:
                print("Graph contains negative weight cycle")
                return

        # Print the shortest distances
        for i in range(self.V):
            print(f"Vertex {i} -> Distance from Source: {dist[i]}")


# Example usage:
if __name__ == "__main__":
    g = Graph(5)
    g.add_edge(0, 1, -1)
    g.add_edge(0, 2, 4)
    g.add_edge(1, 2, 3)
    g.add_edge(1, 3, 2)
    g.add_edge(1, 4, 2)
    g.add_edge(3, 2, 5)
    g.add_edge(3, 1, 1)
    g.add_edge(4, 3, -3)

    g.bellman_ford(0)
# Out:
# Vertex 0 -> Distance from Source: 0
# Vertex 1 -> Distance from Source: -1
# Vertex 2 -> Distance from Source: 2
# Vertex 3 -> Distance from Source: -2
# Vertex 4 -> Distance from Source: 1

# %%
import socket
import time
server_add=('localhost',12345)
sock=socket.socket(socket.AF_INET,socket.SOCK_DGRM)
window_size=3
sequence_number=0
base=0
sent_times=[0]*window_size
rtt=0.1
packet_loss_rate=0.1
congestion_delay=0.05
ack_delay=0.02
data_to_send=["packet"+str(i) for i in range(10)]
while base<len(data_to_send):
    while sequence_number<base+window_size:
        if sequence_number<len(data_to_send):
            packet=data_to_send[sequence_number]
            print(f"sending:{packet}")
            sock.sendto(packet.encode(),server_add)
            sent_times[sequence_number%window_size]=time.time()
            
        sequence_number+=1
        
    while True:
        try:

# %%
def max_subarray_sum(arr):
    max_sum=arr[0]
    curr_sum=arr[0]
    
    for num in arr[1:]:
        curr_sum=max(num,curr_sum+num)
        max_sum=max(max_sum,curr_sum)
    return max_sum

# %%
def find_subarrays(arr):
    subarray=[]
    n=len(arr)
    for i in range(n):
        for j in range(i,n):
            subarrays.append(arr[i:j+1])
    return subarrys

# %%
def subarray_with_sum(arr,target):
    n=len(arr)
    curr_sum=arr[0]
    start=0
    for end in range(1,n):
        while curr_sum>target and start<end:
            curr_sum-=arr[start]
            start+=1
            
            if curr_sum==target:
                return arr[start:end+1]
            curr_sum +=arr[end]
    return None

# %%
def product(arr):
    n=len(arr)
    prod=1
    for i in range(n):
        for j in range(i,n):
            sub_prod=1
            for k in range(i,j+1):
                sub_prod*=arr[k]
            prod*=sub_prod
            
    return prod

# %%
def rotleft(arr,k):
    n=len(arr)
    k%=n
    return arr[k:]+arr[:k]

def rotright(arr,k):
    n=len(arr)
    k%=n
    return arr[-k:]+arr[:-k]

# %%
def is_string_rotation(s1,s2):
    if len(s1)!=len(s2):
        return False
    s2+=s1
    return s1 in s2

def strrot(s,n):
    return s[n:]+s[:n]
def strle(s,n):
    return s[-n:]+s[:-n]

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class LinkedList:
    def __init__(self):
        self.head=None
        
    def append(self,data):
        new_node=Node(data)
        if not self.head:
            self.head=new_node
            return
        curr=self.head
        while curr.next:
            curr=curr.next
        curr.next=new_node
        
    def display(self):
        curr=self.head
        while curr:
            print(curr.data,end="")
            curr=curr.next
        print("None")
        
sll = LinkedList()
sll.append(1)
sll.append(2)
sll.append(3)
sll.display()
# Out:
# 123None

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None
        
class DoublyLinkedList:
    def __init__(self):
        self.head=None
        
    def append(self,data):
        temp=Node(data)
        if not self.head:
            self.head=temp
        else:
            curr=self.head
            while curr.next:
                curr=curr.next
            curr.next=temp
            temp.prev=curr
    def display(self):
        temp=self.head
        while temp:
            print(temp.data,end="")
            temp=temp.next
        print("None")

# %%
def delete(self,data):
    if not self.head:
        return 
    if self.head.data==data:
        self.head=self.head.next
        return
    
    curr=self.head
    while curr.next:
        if curr.next.data==data:
            curr.next=curr.next.next
            return
        curr=curr.next

# %%
def delete(self,data):
    if not self.head:
        return
    if self.head.data==data:
        self.head=self.head.next
        if self.head:
            self.head.prev=None
        return
    curr=self.head
    while curr:
        if curr.data==data:
            curr.prev.next=curr.next
            if curr.next:
                curr.next.prev=curr.prev
            return
        curr=curr.next

# %%
# Reverse linked list
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class LinkedList:
    def __init__(self):
        self.head=None
        
    def reverse(self):
        prev=None
        curr=self.head
        while curr is not None:
            next_node=curr.next
            curr.next=prev
            prev=curr
            curr=next_node
        self.head=prev
        
    def append(self,data):
        temp=Node(data)
        if not self.head:
            self.head=temp
            return
        curr=self.head
        while curr.next:
            curr=curr.next
        curr.next=temp

# %%
def remove_duplicates(self):
    if not self.head:
        return
    unique_val=set()
    curr=self.head
    prev=None
    while curr:
        if curr.data in unique_val:
            prev.next=curr.next
        else:
            unique_val.add(curr.data)
            prev=curr
        curr=curr.next

# %%
def union(ll1,ll2):
    res=linkedlist()
    kanaka=set()
    
    curr=ll1.head
    while curr:
        if curr.data not in kanaka:
            res.append(curr.data)
            kanaka.add(curr.data)
        curr=curr.next
        
    curr=ll2.head
    while curr:
        if curr.data not in kanaka:
            res.append(curr.data)
            kanaka.add(curr.data)
        curr=curr.next
        
    return res

# %%
class ListNode:
    def __init__(self,val):
        self.value=value
        self.next=None
        
def findIntersection(head1,head2):
    #to find lenght we need to take helepr finction
    def get_len(head):
        length=0
        while head:
            length+=1
            head=head.next
        return length
    len1=get_len(head1)
    len2=get_len(head2)
    
    
    ptr1,ptr2=head1,head2
    
    if len1>len2:
        for _ in range(len1-len2):
            ptr1=ptr1.next
            
    else:
        for _ in range(len2-len1):
            ptr2=ptr2.next
            
    while ptr1!=ptr2:
        ptr1=ptr1.next
        ptr2=ptr2.next
    return ptr
